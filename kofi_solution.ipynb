# %% [markdown]
# ## Basic Info

# %%
import pandas as pd

# %%
df = pd.read_csv(
    "movie_data.txt", 
    delimiter = "\t", 
    names = ["ID","title","year",
             "rating","votes",
             "duration","genres"],
    index_col=0)

# %%
df.head()
# Out:
#                                      title  year  rating   votes   duration  \
# ID
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                      genres
# ID
# tt0111161                       Crime|Drama
# tt0110912                    Crime|Thriller
# tt0137523            Drama|Mystery|Thriller
# tt0133093           Action|Adventure|Sci-Fi
# tt1375666  Action|Adventure|Sci-Fi|Thriller

# %%
df.tail(11)
# Out:
#                                          title  year  rating  votes  \
# ID
# tt0101356                   Another You (1991)  1991     4.9   1359
# tt0421090                    Zerophilia (2005)  2005     6.3   1359
# tt0067227  The Merchant of Four Seasons (1971)  1971     7.6   1359
# tt0339727                     Stateside (2004)  2004     5.8   1358
# tt0218581                  Scarlet Diva (2000)  2000     5.2   1358
# tt0118635                        Aprile (1998)  1998     6.7   1358
# tt0807721                       Meduzot (2007)  2007     7.0   1357
# tt0339642                Daltry Calhoun (2005)  2005     5.2   1357
# tt0060880        The Quiller Memorandum (1966)  1966     6.5   1356
# tt0152836                          Taal (1999)  1999     6.5   1356
# tt0279977                The Navigators (2001)  2001     6.9   1356
#
#             duration                      genres
# ID
# tt0101356   98 mins.                Comedy|Crime
# tt0421090   90 mins.              Comedy|Romance
# tt0067227   88 mins.                       Drama
# tt0339727   97 mins.         Drama|Music|Romance
# tt0218581   91 mins.                       Drama
# tt0118635   78 mins.                      Comedy
# tt0807721   78 mins.                       Drama
# tt0339642  100 mins.  Comedy|Drama|Music|Romance
# tt0060880  104 mins.      Drama|Mystery|Thriller
# tt0152836  179 mins.             Musical|Romance
# tt0279977   96 mins.                Comedy|Drama

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, tt0111161 to tt0279977
# Data columns (total 6 columns):
# title       10000 non-null object
# year        10000 non-null int64
# rating      10000 non-null float64
# votes       10000 non-null int64
# duration    10000 non-null object
# genres      9999 non-null object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 546.9+ KB

# %% [markdown]
# ## Cleaning

# %%
df = df.dropna(axis = 1)
print(df.columns)
# Out:
# Index(['title', 'year', 'rating', 'votes', 'duration'], dtype='object')

# %%
df.duration = df.duration.apply(lambda dur:int(dur.split(" ")[0])*60)


df.title = df.title.apply(lambda title: title.split("(")[0])
print(df.columns)
df.head()
# Out:
# Index(['title', 'year', 'rating', 'votes', 'duration'], dtype='object')
#                                title  year  rating   votes  duration
# ID
# tt0111161  The Shawshank Redemption   1994     9.2  619479      8520
# tt0110912              Pulp Fiction   1994     9.0  490065      9240
# tt0137523                Fight Club   1999     8.8  458173      8340
# tt0133093                The Matrix   1999     8.7  448114      8160
# tt1375666                 Inception   2010     8.9  385149      8880

# %% [markdown]
# ## Concatenating and Merging Data Frames

# %% [markdown]
# ### Loading Movie Crew data

# %%
movie_crew_df = pd.read_csv("crew_data.tsv",
                            delimiter = "\t",
                           names=["ID","directors","writers"],
                           index_col=0,
                           skiprows=1,
                           usecols=["ID","directors"])
movie_crew_df.columns
# Out:
# Index(['directors'], dtype='object')

# %%
movie_crew_df.head()
# Out:
#            directors
# ID
# tt0000001  nm0005690
# tt0000002  nm0721526
# tt0000003  nm0721526
# tt0000004  nm0721526
# tt0000005  nm0005690

# %% [markdown]
# ### Loading Person Data

# %%
person_df = pd.read_csv("name_data.tsv",
                       delimiter="\t",
                        names=["nconst","primaryName"],
                       usecols=["nconst","primaryName"],
                       skiprows=1)
person_df.columns = ["person_ID","name"]
person_df.set_index = 0

# %%
person_df.head()
# Out:
#    person_ID             name
# 0  nm0000001     Fred Astaire
# 1  nm0000002    Lauren Bacall
# 2  nm0000003  Brigitte Bardot
# 3  nm0000004     John Belushi
# 4  nm0000005   Ingmar Bergman

# %% [markdown]
# ### Merging Crew and Movie Data

# %%
df=pd.merge(df, movie_crew_df,left_index=True,right_index=True)
df.head()
# Out:
#                                title  year  rating   votes  duration  \
# ID
# tt0111161  The Shawshank Redemption   1994     9.2  619479      8520
# tt0110912              Pulp Fiction   1994     9.0  490065      9240
# tt0137523                Fight Club   1999     8.8  458173      8340
# tt0133093                The Matrix   1999     8.7  448114      8160
# tt1375666                 Inception   2010     8.9  385149      8880
#
#                      directors
# ID
# tt0111161            nm0001104
# tt0110912            nm0000233
# tt0137523            nm0000399
# tt0133093  nm0905154,nm0905152
# tt1375666            nm0634240

# %% [markdown]
# #### Dealing with multiple directors

# %%
df = df[df['directors'].str.contains(",")==False]
df.rename(columns={'directors':'director_id'},inplace=True)
df.head()
# Out:
#                                title  year  rating   votes  duration  \
# ID
# tt0111161  The Shawshank Redemption   1994     9.2  619479      8520
# tt0110912              Pulp Fiction   1994     9.0  490065      9240
# tt0137523                Fight Club   1999     8.8  458173      8340
# tt1375666                 Inception   2010     8.9  385149      8880
# tt0109830              Forrest Gump   1994     8.7  368994      8520
#
#           director_id
# ID
# tt0111161   nm0001104
# tt0110912   nm0000233
# tt0137523   nm0000399
# tt1375666   nm0634240
# tt0109830   nm0000709

# %% [markdown]
# ### Merging with Person Data

# %%
df = pd.merge(df,person_df,
              left_on='director_id',
              right_on='person_ID')
df.head()
# Out:
#                        title  year  rating   votes  duration director_id  \
# 0  The Shawshank Redemption   1994     9.2  619479      8520   nm0001104
# 1            The Green Mile   1999     8.4  243660     11340   nm0001104
# 2                  The Mist   2007     7.4   90987      7560   nm0001104
# 3              The Majestic   2001     6.8   27241      9120   nm0001104
# 4              Pulp Fiction   1994     9.0  490065      9240   nm0000233
#
#    person_ID               name
# 0  nm0001104     Frank Darabont
# 1  nm0001104     Frank Darabont
# 2  nm0001104     Frank Darabont
# 3  nm0001104     Frank Darabont
# 4  nm0000233  Quentin Tarantino

# %%
df.rename(columns={'name':'director'},inplace=True)
df.head()
# Out:
#                        title  year  rating   votes  duration director_id  \
# 0  The Shawshank Redemption   1994     9.2  619479      8520   nm0001104
# 1            The Green Mile   1999     8.4  243660     11340   nm0001104
# 2                  The Mist   2007     7.4   90987      7560   nm0001104
# 3              The Majestic   2001     6.8   27241      9120   nm0001104
# 4              Pulp Fiction   1994     9.0  490065      9240   nm0000233
#
#    person_ID           director
# 0  nm0001104     Frank Darabont
# 1  nm0001104     Frank Darabont
# 2  nm0001104     Frank Darabont
# 3  nm0001104     Frank Darabont
# 4  nm0000233  Quentin Tarantino

# %% [markdown]
# #### Extra clean up

# %%
df = df.drop(columns=["person_ID"])
df.head()
# Out:
#                        title  year  rating   votes  duration director_id  \
# 0  The Shawshank Redemption   1994     9.2  619479      8520   nm0001104
# 1            The Green Mile   1999     8.4  243660     11340   nm0001104
# 2                  The Mist   2007     7.4   90987      7560   nm0001104
# 3              The Majestic   2001     6.8   27241      9120   nm0001104
# 4              Pulp Fiction   1994     9.0  490065      9240   nm0000233
#
#             director
# 0     Frank Darabont
# 1     Frank Darabont
# 2     Frank Darabont
# 3     Frank Darabont
# 4  Quentin Tarantino

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Ten longest movies

# %%
result=df.sort_values(["duration"], ascending=[False])
result.head(10)
# Out:
#                                    title  year  rating  votes  duration  \
# 8060                         Satantango   1994     8.5   2698     27000
# 7959                      War and Peace   1967     7.8   2833     25620
# 5230                         Gettysburg   1993     7.7  12093     15660
# 1941                             Hamlet   1996     7.7  19698     14520
# 6246                      Love Exposure   2008     8.0   1922     14220
# 8132                  La Belle Noiseuse   1991     7.6   2621     14160
# 6126                             Ludwig   1972     7.6   1581     14100
# 341         Once Upon a Time in America   1984     8.4  85533     13740
# 4881  Lagaan: Once Upon a Time in India   2001     8.1  14190     13440
# 3956               The Ten Commandments   1956     7.9  22789     13200
#
#      director_id            director
# 8060   nm0850601           Béla Tarr
# 7959   nm0094083   Sergey Bondarchuk
# 5230   nm0561813         Ron Maxwell
# 1941   nm0000110     Kenneth Branagh
# 6246   nm0814469           Sion Sono
# 8132   nm0729626     Jacques Rivette
# 6126   nm0899581    Luchino Visconti
# 341    nm0001466        Sergio Leone
# 4881   nm0332950  Ashutosh Gowariker
# 3956   nm0001124    Cecil B. DeMille

# %% [markdown]
# ### Best rated movies ordered by Rating and Title

# %%
result=df.sort_values(["rating","title"],ascending=[False,True])
result.head(10)
# Out:
#                                  title  year  rating   votes  duration  \
# 145                     The Godfather   1972     9.2  474189     10500
# 0            The Shawshank Redemption   1994     9.2  619479      8520
# 5636                 Outrageous Class   1975     9.0    9823      5220
# 4                        Pulp Fiction   1994     9.0  490065      9240
# 146            The Godfather: Part II   1974     9.0  291169     12000
# 339    The Good, the Bad and the Ugly   1966     9.0  195238      9660
# 631                      12 Angry Men   1957     8.9  148155      5760
# 18                          Inception   2010     8.9  385149      8880
# 215   One Flew Over the Cuckoo's Nest   1975     8.9  255503      7980
# 52                   Schindler's List   1993     8.9  325888     11700
#
#      director_id              director
# 145    nm0000338  Francis Ford Coppola
# 0      nm0001104        Frank Darabont
# 5636   nm0251027         Ertem Egilmez
# 4      nm0000233     Quentin Tarantino
# 146    nm0000338  Francis Ford Coppola
# 339    nm0001466          Sergio Leone
# 631    nm0001486          Sidney Lumet
# 18     nm0634240     Christopher Nolan
# 215    nm0001232          Milos Forman
# 52     nm0000229      Steven Spielberg

# %% [markdown]
# ### Average Duration of a Movie

# %%
result = df.duration.mean()
print(result)
print(f"The average duration of a movie is {result/60}")
# Out:
# 6242.946031746032
# The average duration of a movie is 104.04910052910053

# %% [markdown]
# ### Ten most productive directors

# %%
grouped = df.groupby(["director"])[["director"]].count()
grouped.rename(columns={"director":"count"},inplace=True)
grouped.head()
# Out:
#                   count
# director
# A.R. Murugadoss       1
# Aaron Norris          3
# Aaron Schneider       1
# Abbas Kiarostami      7
# Abbas Tyrewala        1

# %%
result= grouped.sort_values(["count"],ascending=[False])
result.head(10)
# Out:
#                   count
# director
# Woody Allen          40
# Clint Eastwood       31
# Sidney Lumet         27
# Steven Spielberg     24
# Robert Altman        24
# Brian De Palma       23
# John Huston          23
# Joel Schumacher      22
# Martin Scorsese      21
# Blake Edwards        21

# %% [markdown]
# ### How many movies were made in the 2000's

# %%
result=df[(df.year>1999) & (df.year<2010)].year.count()
print(f"The number of movies made in the 2000s is {result}")
# Out:
# The number of movies made in the 2000s is 3903

# %% [markdown]
# ### Movies made by Akira Kurosawa ordered by year DESC

# %%
result=df[df.director=="Akira Kurosawa"].sort_values(["year"],ascending=[False])[["title","year","director"]]
result.head(20)
# Out:
#                     title  year        director
# 868             Madadayo   1993  Akira Kurosawa
# 866   Rhapsody in August   1991  Akira Kurosawa
# 855                  Ran   1985  Akira Kurosawa
# 860            Kagemusha   1980  Akira Kurosawa
# 862          Dersu Uzala   1975  Akira Kurosawa
# 867         Dodes'ka-den   1970  Akira Kurosawa
# 864            Red Beard   1965  Akira Kurosawa
# 863         High and Low   1963  Akira Kurosawa
# 861              Sanjuro   1962  Akira Kurosawa
# 856              Yojimbo   1961  Akira Kurosawa
# 865   The Bad Sleep Well   1960  Akira Kurosawa
# 859  The Hidden Fortress   1958  Akira Kurosawa
# 869     The Lower Depths   1957  Akira Kurosawa
# 858      Throne of Blood   1957  Akira Kurosawa
# 871       I Live in Fear   1955  Akira Kurosawa
# 853        Seven Samurai   1954  Akira Kurosawa
# 857                Ikiru   1952  Akira Kurosawa
# 870            The Idiot   1951  Akira Kurosawa
# 854             Rashomon   1950  Akira Kurosawa
