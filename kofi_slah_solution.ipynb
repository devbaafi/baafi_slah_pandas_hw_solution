# %% [markdown]
# ## About Pandas

# %% [markdown]
# Pandas is one of the most popular tools for data wrangling, preparation, analysis and modelling. It allows python developers to work on various data sources including delimited files, html pages(requires the presence of table tags), json, hdf5 files, sql data from databases etc. This makes it a very versatile tool to working with data.Pandas also offers apis to manipulate data such as filtering, indexing, grouping by and aggregate functions such as mean, standard deviation, kurtosis, etc. It also allows manipulation of data using regular and lambda functions. SQL-like functions make it possible to perform cartesian joins using functions like `join` and `merge`. For data cleaning operations, offers functions for checking for nulls, handling nulls, dropping rows and columns.

# %% [markdown]
# ## Basic Info

# %%
import pandas as pd

# %%
df = pd.read_csv(
    "movie_data.txt", 
    delimiter = "\t", 
    names = ["ID","title","year",
             "rating","votes",
             "duration","genres"],
    index_col=0)

# Printing first 5 elements

df.head()
# Out:
#                                      title  year  rating   votes   duration  \
# ID
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                      genres
# ID
# tt0111161                       Crime|Drama
# tt0110912                    Crime|Thriller
# tt0137523            Drama|Mystery|Thriller
# tt0133093           Action|Adventure|Sci-Fi
# tt1375666  Action|Adventure|Sci-Fi|Thriller

# %%
# Printing last 11 elements
df.tail(11)
# Out:
#                                          title  year  rating  votes  \
# ID
# tt0101356                   Another You (1991)  1991     4.9   1359
# tt0421090                    Zerophilia (2005)  2005     6.3   1359
# tt0067227  The Merchant of Four Seasons (1971)  1971     7.6   1359
# tt0339727                     Stateside (2004)  2004     5.8   1358
# tt0218581                  Scarlet Diva (2000)  2000     5.2   1358
# tt0118635                        Aprile (1998)  1998     6.7   1358
# tt0807721                       Meduzot (2007)  2007     7.0   1357
# tt0339642                Daltry Calhoun (2005)  2005     5.2   1357
# tt0060880        The Quiller Memorandum (1966)  1966     6.5   1356
# tt0152836                          Taal (1999)  1999     6.5   1356
# tt0279977                The Navigators (2001)  2001     6.9   1356
#
#             duration                      genres
# ID
# tt0101356   98 mins.                Comedy|Crime
# tt0421090   90 mins.              Comedy|Romance
# tt0067227   88 mins.                       Drama
# tt0339727   97 mins.         Drama|Music|Romance
# tt0218581   91 mins.                       Drama
# tt0118635   78 mins.                      Comedy
# tt0807721   78 mins.                       Drama
# tt0339642  100 mins.  Comedy|Drama|Music|Romance
# tt0060880  104 mins.      Drama|Mystery|Thriller
# tt0152836  179 mins.             Musical|Romance
# tt0279977   96 mins.                Comedy|Drama

# %%
# Printing data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, tt0111161 to tt0279977
# Data columns (total 6 columns):
# title       10000 non-null object
# year        10000 non-null int64
# rating      10000 non-null float64
# votes       10000 non-null int64
# duration    10000 non-null object
# genres      9999 non-null object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 546.9+ KB

# %% [markdown]
# ## Cleaning

# %% [markdown]
# ### Removing missing rows

# %%
df = df.dropna(axis = 1)
print(df.columns)
# Out:
# Index(['title', 'year', 'rating', 'votes', 'duration'], dtype='object')

# %% [markdown]
# ### Converting duration of column to numerical representation in seconds

# %%
df.duration = df.duration.apply(lambda dur:int(dur.split(" ")[0])*60)
df.head()
# Out:
#                                      title  year  rating   votes  duration
# ID
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479      8520
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065      9240
# tt0137523                Fight Club (1999)  1999     8.8  458173      8340
# tt0133093                The Matrix (1999)  1999     8.7  448114      8160
# tt1375666                 Inception (2010)  2010     8.9  385149      8880

# %% [markdown]
# ### Removing year from the title column

# %%
df.title = df.title.apply(lambda title: title.split("(")[0])
print(df.columns)
df.head()
# Out:
# Index(['title', 'year', 'rating', 'votes', 'duration'], dtype='object')
#                                title  year  rating   votes  duration
# ID
# tt0111161  The Shawshank Redemption   1994     9.2  619479      8520
# tt0110912              Pulp Fiction   1994     9.0  490065      9240
# tt0137523                Fight Club   1999     8.8  458173      8340
# tt0133093                The Matrix   1999     8.7  448114      8160
# tt1375666                 Inception   2010     8.9  385149      8880

# %% [markdown]
# ## Concatenating
#
# 1. Read `crew_data.tsv.gz` to DataFrame named `movie_crew_df` with columns `ID, director_ids` indexed by `ID` (forget the rest of the columns)
# 2. Read `person_data.tsv.gz` to DataFrame named `person_df` with columns `person_ID, name` indexed by `person_ID` (forget the rest of the columns)
# 3. Merge `movie_crew_df` into `df` with `ID`s and drop the columns without necessary data (hint `outer`-join)
# 4. Remove movies with more than one director and rename `director_ids` => `director_id`
# 5. Merge `df` with `person_df` on `director_id`, remove `director_id` and `person_ID` columns, rename `name` => `director`

# %% [markdown]
# ### loading movie crew data

# %%
movie_crew_df = pd.read_csv('crew_data (1).tsv.gz', header=0, delimiter = '\t', usecols=(0,1) , names=['ID','director_ids'])
movie_crew_df.head()
# Out:
#           ID director_ids
# 0  tt0000001    nm0005690
# 1  tt0000002    nm0721526
# 2  tt0000003    nm0721526
# 3  tt0000004    nm0721526
# 4  tt0000005    nm0005690

# %% [markdown]
# ### loading person name data

# %%
person_df = pd.read_csv('name_data (2).tsv.gz', header = 0, delimiter = '\t', usecols= (0,1) , names=['person_ID','name'])
person_df.head()
# Out:
#    person_ID             name
# 0  nm0000001     Fred Astaire
# 1  nm0000002    Lauren Bacall
# 2  nm0000003  Brigitte Bardot
# 3  nm0000004     John Belushi
# 4  nm0000005   Ingmar Bergman

# %% [markdown]
# ### Merge movie crew data with movie data

# %%
df = pd.merge(df, movie_crew_df, on ="ID", how='outer')
df.head()
# Out:
#           ID                      title    year  rating     votes  duration  \
# 0  tt0111161  The Shawshank Redemption   1994.0     9.2  619479.0    8520.0
# 1  tt0110912              Pulp Fiction   1994.0     9.0  490065.0    9240.0
# 2  tt0137523                Fight Club   1999.0     8.8  458173.0    8340.0
# 3  tt0133093                The Matrix   1999.0     8.7  448114.0    8160.0
# 4  tt1375666                 Inception   2010.0     8.9  385149.0    8880.0
#
#           director_ids
# 0            nm0001104
# 1            nm0000233
# 2            nm0000399
# 3  nm0905154,nm0905152
# 4            nm0634240

# %% [markdown]
# ### dealing with multiple directors

# %%
df = df[df['director_ids'].str.contains(",")==False]
df.rename(columns={'director_ids':'director_id'},inplace=True)
df.head()
# Out:
#           ID                      title    year  rating     votes  duration  \
# 0  tt0111161  The Shawshank Redemption   1994.0     9.2  619479.0    8520.0
# 1  tt0110912              Pulp Fiction   1994.0     9.0  490065.0    9240.0
# 2  tt0137523                Fight Club   1999.0     8.8  458173.0    8340.0
# 4  tt1375666                 Inception   2010.0     8.9  385149.0    8880.0
# 5  tt0109830              Forrest Gump   1994.0     8.7  368994.0    8520.0
#
#   director_id
# 0   nm0001104
# 1   nm0000233
# 2   nm0000399
# 4   nm0634240
# 5   nm0000709

# %% [markdown]
# ### merging person data and movie data

# %%
df = pd.merge(df, person_df, left_on ="director_id", right_on='person_ID', how='inner')
df.head()
# Out:
#           ID                      title    year  rating     votes  duration  \
# 0  tt0111161  The Shawshank Redemption   1994.0     9.2  619479.0    8520.0
# 1  tt0120689            The Green Mile   1999.0     8.4  243660.0   11340.0
# 2  tt0884328                  The Mist   2007.0     7.4   90987.0    7560.0
# 3  tt0268995              The Majestic   2001.0     6.8   27241.0    9120.0
# 4  tt0086534                        NaN     NaN     NaN       NaN       NaN
#
#   director_id  person_ID            name
# 0   nm0001104  nm0001104  Frank Darabont
# 1   nm0001104  nm0001104  Frank Darabont
# 2   nm0001104  nm0001104  Frank Darabont
# 3   nm0001104  nm0001104  Frank Darabont
# 4   nm0001104  nm0001104  Frank Darabont

# %%
df.rename(columns={'name':'director'},inplace=True)

# %%
df.head()
# Out:
#           ID                      title    year  rating     votes  duration  \
# 0  tt0111161  The Shawshank Redemption   1994.0     9.2  619479.0    8520.0
# 1  tt0120689            The Green Mile   1999.0     8.4  243660.0   11340.0
# 2  tt0884328                  The Mist   2007.0     7.4   90987.0    7560.0
# 3  tt0268995              The Majestic   2001.0     6.8   27241.0    9120.0
# 4  tt0086534                        NaN     NaN     NaN       NaN       NaN
#
#   director_id  person_ID        director
# 0   nm0001104  nm0001104  Frank Darabont
# 1   nm0001104  nm0001104  Frank Darabont
# 2   nm0001104  nm0001104  Frank Darabont
# 3   nm0001104  nm0001104  Frank Darabont
# 4   nm0001104  nm0001104  Frank Darabont

# %% [markdown]
# Extra clean up

# %%
df = df.drop(columns=["person_ID"])
df.head()
# Out:
#           ID                      title    year  rating     votes  duration  \
# 0  tt0111161  The Shawshank Redemption   1994.0     9.2  619479.0    8520.0
# 1  tt0120689            The Green Mile   1999.0     8.4  243660.0   11340.0
# 2  tt0884328                  The Mist   2007.0     7.4   90987.0    7560.0
# 3  tt0268995              The Majestic   2001.0     6.8   27241.0    9120.0
# 4  tt0086534                        NaN     NaN     NaN       NaN       NaN
#
#   director_id        director
# 0   nm0001104  Frank Darabont
# 1   nm0001104  Frank Darabont
# 2   nm0001104  Frank Darabont
# 3   nm0001104  Frank Darabont
# 4   nm0001104  Frank Darabont

# %% [markdown]
# ## Exploration
#
# 1. Find ten most longest movies
# 2. Find Best rated movies ordered by rating DESC and Title ASC
# 3. What is the average duration (in minutes) of a movie?
# 4. Get ten most productive directors
# 5. How many movie has been made in the 2000's?
# 6. Get all the movies directed by Akira Kurosawa ordered by year DESC

# %% [markdown]
# ### ten longest movies

# %%
df = df.sort_values('duration', ascending = False)
df.head(10)
# Out:
#               ID                               title    year  rating    votes  \
# 82067  tt0111341                         Satantango   1994.0     8.5   2698.0
# 80924  tt0063794                      War and Peace   1967.0     7.8   2833.0
# 37483  tt0107007                         Gettysburg   1993.0     7.7  12093.0
# 9226   tt0116477                             Hamlet   1996.0     7.7  19698.0
# 53880  tt1128075                      Love Exposure   2008.0     8.0   1922.0
# 83247  tt0101428                  La Belle Noiseuse   1991.0     7.6   2621.0
# 52013  tt0068883                             Ludwig   1972.0     7.6   1581.0
# 1342   tt0087843        Once Upon a Time in America   1984.0     8.4  85533.0
# 32903  tt0169102  Lagaan: Once Upon a Time in India   2001.0     8.1  14190.0
# 23093  tt0049833               The Ten Commandments   1956.0     7.9  22789.0
#
#        duration director_id            director
# 82067   27000.0   nm0850601           Béla Tarr
# 80924   25620.0   nm0094083   Sergey Bondarchuk
# 37483   15660.0   nm0561813         Ron Maxwell
# 9226    14520.0   nm0000110     Kenneth Branagh
# 53880   14220.0   nm0814469           Sion Sono
# 83247   14160.0   nm0729626     Jacques Rivette
# 52013   14100.0   nm0899581    Luchino Visconti
# 1342    13740.0   nm0001466        Sergio Leone
# 32903   13440.0   nm0332950  Ashutosh Gowariker
# 23093   13200.0   nm0001124    Cecil B. DeMille

# %% [markdown]
# ### best rated movies

# %%
df = df.sort_values(by=['rating','title'], ascending=[False,True])
df.head()
# Out:
#               ID                      title    year  rating     votes  \
# 525    tt0068646             The Godfather   1972.0     9.2  474189.0
# 0      tt0111161  The Shawshank Redemption   1994.0     9.2  619479.0
# 44369  tt0252487          Outrageous Class   1975.0     9.0    9823.0
# 14     tt0110912              Pulp Fiction   1994.0     9.0  490065.0
# 526    tt0071562    The Godfather: Part II   1974.0     9.0  291169.0
#
#        duration director_id              director
# 525     10500.0   nm0000338  Francis Ford Coppola
# 0        8520.0   nm0001104        Frank Darabont
# 44369    5220.0   nm0251027         Ertem Egilmez
# 14       9240.0   nm0000233     Quentin Tarantino
# 526     12000.0   nm0000338  Francis Ford Coppola

# %% [markdown]
# ### Average duration of movie

# %%
df['duration'].mean()/60
# Out:
# 104.04910052910053

# %% [markdown]
# ### 10 most productive directors

# %%
print(df.nlargest(10,'votes'))
# Out:
#             ID                                              title    year  \
# 0    tt0111161                          The Shawshank Redemption   1994.0
# 114  tt0468569                                   The Dark Knight   2008.0
# 14   tt0110912                                      Pulp Fiction   1994.0
# 525  tt0068646                                     The Godfather   1972.0
# 30   tt0137523                                        Fight Club   1999.0
# 561  tt0120737  The Lord of the Rings: The Fellowship of the R...  2001.0
# 562  tt0167260     The Lord of the Rings: The Return of the King   2003.0
# 111  tt1375666                                         Inception   2010.0
# 563  tt0167261             The Lord of the Rings: The Two Towers   2002.0
# 125  tt0109830                                      Forrest Gump   1994.0
#
#      rating     votes  duration director_id              director
# 0       9.2  619479.0    8520.0   nm0001104        Frank Darabont
# 114     8.9  555122.0    9120.0   nm0634240     Christopher Nolan
# 14      9.0  490065.0    9240.0   nm0000233     Quentin Tarantino
# 525     9.2  474189.0   10500.0   nm0000338  Francis Ford Coppola
# 30      8.8  458173.0    8340.0   nm0000399         David Fincher
# 561     8.8  451263.0   10680.0   nm0001392         Peter Jackson
# 562     8.8  428791.0   12060.0   nm0001392         Peter Jackson
# 111     8.9  385149.0    8880.0   nm0634240     Christopher Nolan
# 563     8.7  383113.0   10740.0   nm0001392         Peter Jackson
# 125     8.7  368994.0    8520.0   nm0000709       Robert Zemeckis

# %% [markdown]
# ### movies in 2000s

# %%
df[df['year'] > 2000]
# Out:
#                ID                                              title    year  \
# 111     tt1375666                                         Inception   2010.0
# 114     tt0468569                                   The Dark Knight   2008.0
# 561     tt0120737  The Lord of the Rings: The Fellowship of the R...  2001.0
# 562     tt0167260     The Lord of the Rings: The Return of the King   2003.0
# 33094   tt0476735                              My Father and My Son   2005.0
# 563     tt0167261             The Lord of the Rings: The Two Towers   2002.0
# 37194   tt1832382                                      A Separation   2011.0
# 2017    tt0435761                                       Toy Story 3   2010.0
# 962     tt0211915                                         Am\xe9lie   2001.0
# 709     tt0338013             Eternal Sunshine of the Spotless Mind   2004.0
# 3099    tt1201607      Harry Potter and the Deathly Hallows: Part 2   2011.0
# 414     tt0407887                                      The Departed   2006.0
# 5208    tt0405094                               The Lives of Others   2006.0
# 1722    tt0253474                                       The Pianist   2002.0
# 518     tt0910970                                         WALL\xb7E   2008.0
# 4432    tt0363163                                          Downfall   2004.0
# 20974   tt1555149                                     Elite Squad 2   2010.0
# 3682    tt0364569                                            Oldboy   2003.0
# 1143    tt0457430                                   Pan's Labyrinth   2006.0
# 113     tt0482571                                      The Prestige   2006.0
# 112     tt0372784                                     Batman Begins   2005.0
# 1297    tt0947798                                        Black Swan   2010.0
# 1662    tt1205489                                       Gran Torino   2008.0
# 3940    tt0395169                                      Hotel Rwanda   2004.0
# 22679   tt0306846                                  No Pain, No Gain   2005.0
# 60841   tt0314067                                      Philanthropy   2002.0
# 45412   tt0346336                                 The Best of Youth   2003.0
# 4091    tt1504320                                 The King's Speech   2010.0
# 16804   tt1305806                          The Secret in Their Eyes   2009.0
# 71053   tt1639426                                             Udaan   2010.0
# ...           ...                                                ...     ...
# 94527   tt0318497                                        Nine Lives   2002.0
# 114361  tt0415345                                     Seven Mummies   2006.0
# 85529   tt0756703                                    Feel the Noise   2007.0
# 107890  tt0395669                Miss Castaway and the Island Girls   2004.0
# 35683   tt1343704                                   Time You Change   2010.0
# 78355   tt0315775                                      Anne B. Real   2003.0
# 105573  tt0426550                                           Popstar   2005.0
# 117770  tt1316037                        Birdemic: Shock and Terror   2008.0
# 32193   tt0118589                                           Glitter   2001.0
# 19921   tt0317676                                 House of the Dead   2003.0
# 25024   tt0362165                                   Son of the Mask   2005.0
# 73291   tt0456014                                       Surf School   2006.0
# 68897   tt0470833                     Keloglan vs. the Black Prince   2006.0
# 97376   tt0451109                              The Maize: The Movie   2004.0
# 51670   tt0473024                                         Crossover   2006.0
# 62379   tt0382028                                         Fat Slags   2004.0
# 92779   tt0958824                                    The Apocalypse   2007.0
# 21593   tt0804492                           The Hottie & the Nottie   2008.0
# 54905   tt0808240                                    Turks in Space   2006.0
# 38285   tt0785077                                 Who's Your Caddy?   2007.0
# 18034   tt0339034                              From Justin to Kelly   2003.0
# 70241   tt0343788                                         The Hillz   2004.0
# 94166   tt0469849                                     Too Beautiful   2005.0
# 49703   tt0469999                                     Zodiac Killer   2005.0
# 79921   tt0473310                   Ram Gopal Varma's Indian Flames   2007.0
# 49702   tt0463392                                     Zombie Nation   2004.0
# 64977   tt0364986                                      Ben & Arthur   2002.0
# 49701   tt0421051                                 Daniel the Wizard   2004.0
# 80770   tt1309000                                        Dream Well   2009.0
# 9851    tt0270846                      Superbabies: Baby Geniuses 2   2004.0
#
#         rating     votes  duration director_id  \
# 111        8.9  385149.0    8880.0   nm0634240
# 114        8.9  555122.0    9120.0   nm0634240
# 561        8.8  451263.0   10680.0   nm0001392
# 562        8.8  428791.0   12060.0   nm0001392
# 33094      8.7   14080.0    6480.0   nm1463981
# 563        8.7  383113.0   10740.0   nm0001392
# 37194      8.6   11954.0    7200.0   nm1410815
# 2017       8.6  144200.0    6180.0   nm0881279
# 962        8.5  215732.0    7320.0   nm0000466
# 709        8.5  260298.0    6480.0   nm0327273
# 3099       8.5   60422.0    7800.0   nm0946734
# 414        8.5  315448.0    9060.0   nm0000217
# 5208       8.5   92399.0    8220.0   nm0003697
# 1722       8.5  162990.0    9000.0   nm0000591
# 518        8.5  229364.0    5880.0   nm0004056
# 4432       8.4   98859.0    9360.0   nm0386570
# 20974      8.4    9060.0    6900.0   nm0655683
# 3682       8.4  119238.0    7200.0   nm0661791
# 1143       8.4  186080.0       0.0   nm0868219
# 113        8.4  258396.0    7800.0   nm0634240
# 112        8.3  316613.0    8400.0   nm0634240
# 1297       8.3  150346.0    6480.0   nm0004716
# 1662       8.3  168721.0    6960.0   nm0000142
# 3940       8.3  109022.0    7260.0   nm0313623
# 22679      8.3   23111.0       0.0   nm0876988
# 60841      8.3    5396.0    6600.0   nm0135952
# 45412      8.3    9110.0   10800.0   nm0320285
# 4091       8.3  101232.0    7080.0   nm0393799
# 16804      8.3   33218.0    7740.0   nm0002728
# 71053      8.3    3832.0    8040.0   nm0003939
# ...        ...       ...       ...         ...
# 94527      2.3    2043.0    5100.0   nm1171292
# 114361     2.3    1460.0    5400.0   nm1516023
# 85529      2.2    2459.0    5160.0   nm1145057
# 107890     2.2    1616.0    5400.0   nm0831546
# 35683      2.2    2944.0    5640.0   nm0248942
# 78355      2.1    3036.0       0.0   nm0289824
# 105573     2.1    1687.0       0.0   nm0299923
# 117770     2.0    1366.0    5400.0   nm1343100
# 32193      2.0   14391.0    6240.0   nm0193554
# 19921      2.0   23103.0    5400.0   nm0093051
# 25024      2.0   18454.0    5640.0   nm0349183
# 73291      2.0    3561.0       0.0   nm0798926
# 68897      1.9    4117.0       0.0   nm1000987
# 97376      1.9    1939.0    6000.0   nm1845037
# 51670      1.8    7577.0    5700.0   nm0926211
# 62379      1.8    1927.0    4500.0   nm0125753
# 92779      1.8    2127.0    5640.0   nm1578111
# 21593      1.8   24021.0    5460.0   nm0701245
# 54905      1.8    6370.0    6600.0   nm0862605
# 38285      1.8   11821.0    5580.0   nm0666806
# 18034      1.7   18107.0    4860.0   nm0410769
# 70241      1.7    3915.0    5460.0   nm1288474
# 94166      1.7    2055.0    5820.0   nm0320306
# 49703      1.7    2255.0    4980.0   nm0518579
# 79921      1.6    2511.0       0.0   nm0890060
# 49702      1.6    4299.0    4860.0   nm0518579
# 64977      1.5    4675.0    5100.0   nm1371524
# 49701      1.5    8271.0    4860.0   nm0518579
# 80770      1.5    2848.0       0.0   nm0286207
# 9851       1.5   13196.0    5280.0   nm0163706
#
#                                 director
# 111                    Christopher Nolan
# 114                    Christopher Nolan
# 561                        Peter Jackson
# 562                        Peter Jackson
# 33094                        Çagan Irmak
# 563                        Peter Jackson
# 37194                     Asghar Farhadi
# 2017                         Lee Unkrich
# 962                   Jean-Pierre Jeunet
# 709                        Michel Gondry
# 3099                         David Yates
# 414                      Martin Scorsese
# 5208    Florian Henckel von Donnersmarck
# 1722                      Roman Polanski
# 518                       Andrew Stanton
# 4432                 Oliver Hirschbiegel
# 20974                       José Padilha
# 3682                      Chan-wook Park
# 1143                  Guillermo del Toro
# 113                    Christopher Nolan
# 112                    Christopher Nolan
# 1297                    Darren Aronofsky
# 1662                      Clint Eastwood
# 3940                        Terry George
# 22679                    Samuel Turcotte
# 60841                       Nae Caranfil
# 45412              Marco Tullio Giordana
# 4091                          Tom Hooper
# 16804               Juan José Campanella
# 71053               Vikramaditya Motwane
# ...                                  ...
# 94527                       Andrew Green
# 114361                      Nick Quested
# 85529                  Alejandro Chomski
# 107890             Bryan Michael Stoller
# 35683                           Uli Edel
# 78355                        Lisa France
# 105573                     Richard Gabai
# 117770                      James Nguyen
# 32193                 Vondie Curtis-Hall
# 19921                           Uwe Boll
# 25024                  Lawrence Guterman
# 73291                     Joel Silverman
# 68897                     Tayfun Güneyer
# 97376                        Bill Cowell
# 51670             Preston A. Whitmore II
# 62379                             Ed Bye
# 92779                       Justin Jones
# 21593                         Tom Putnam
# 54905                       Kartal Tibet
# 38285                   Don Michael Paul
# 18034                      Robert Iscove
# 70241                       Saran Barnun
# 94166              Ugo Fabrizio Giordani
# 49703                        Ulli Lommel
# 79921                    Ram Gopal Varma
# 49702                        Ulli Lommel
# 64977                       Sam Mraovich
# 49701                        Ulli Lommel
# 80770                      Gábor Forgács
# 9851                           Bob Clark
#
# [3978 rows x 8 columns]

# %% [markdown]
# ### all the movies directed by Akira Kurosawa ordered by year DESC

# %%
df[df['director'] == 'Akira Kurosawa'].sort_values(by=['year'], ascending=True)
# Out:
#              ID                 title    year  rating     votes  duration  \
# 3472  tt0042876             Rashomon   1950.0     8.4   46250.0    5280.0
# 3488  tt0043614            The Idiot   1951.0     7.5    1680.0    9960.0
# 3475  tt0044741                Ikiru   1952.0     8.3   18948.0    8580.0
# 3471  tt0047478        Seven Samurai   1954.0     8.8  111707.0   12420.0
# 3489  tt0048198       I Live in Fear   1955.0     7.3    1360.0    6180.0
# 3487  tt0050330     The Lower Depths   1957.0     7.5    1901.0    8220.0
# 3476  tt0050613      Throne of Blood   1957.0     8.1   13559.0    6600.0
# 3477  tt0051808  The Hidden Fortress   1958.0     8.1   12535.0    8340.0
# 3483  tt0054460   The Bad Sleep Well   1960.0     8.0    3356.0    9060.0
# 3474  tt0055630              Yojimbo   1961.0     8.4   33878.0    6600.0
# 3479  tt0056443              Sanjuro   1962.0     8.1    9739.0    5760.0
# 3481  tt0057565         High and Low   1963.0     8.3    8603.0    8520.0
# 3482  tt0058888            Red Beard   1965.0     8.1    5747.0   11100.0
# 3485  tt0065649         Dodes'ka-den   1970.0     7.6    2371.0    8400.0
# 3480  tt0071411          Dersu Uzala   1975.0     8.2    9180.0    8640.0
# 3478  tt0080979            Kagemusha   1980.0     7.9   12492.0   10800.0
# 3473  tt0089881                  Ran   1985.0     8.3   39096.0    9720.0
# 3484  tt0101991   Rhapsody in August   1991.0     7.2    2830.0    5880.0
# 3486  tt0107474             Madadayo   1993.0     7.4    1935.0    8040.0
# 3490  tt0036400                   NaN     NaN     NaN       NaN       NaN
# 3491  tt0036947                   NaN     NaN     NaN       NaN       NaN
# 3492  tt0038182                   NaN     NaN     NaN       NaN       NaN
# 3493  tt0038268                   NaN     NaN     NaN       NaN       NaN
# 3494  tt0039090                   NaN     NaN     NaN       NaN       NaN
# 3495  tt0039871                   NaN     NaN     NaN       NaN       NaN
# 3496  tt0040979                   NaN     NaN     NaN       NaN       NaN
# 3497  tt0041699                   NaN     NaN     NaN       NaN       NaN
# 3498  tt0041870                   NaN     NaN     NaN       NaN       NaN
# 3499  tt0042958                   NaN     NaN     NaN       NaN       NaN
# 3500  tt4346112                   NaN     NaN     NaN       NaN       NaN
#
#      director_id        director
# 3472   nm0000041  Akira Kurosawa
# 3488   nm0000041  Akira Kurosawa
# 3475   nm0000041  Akira Kurosawa
# 3471   nm0000041  Akira Kurosawa
# 3489   nm0000041  Akira Kurosawa
# 3487   nm0000041  Akira Kurosawa
# 3476   nm0000041  Akira Kurosawa
# 3477   nm0000041  Akira Kurosawa
# 3483   nm0000041  Akira Kurosawa
# 3474   nm0000041  Akira Kurosawa
# 3479   nm0000041  Akira Kurosawa
# 3481   nm0000041  Akira Kurosawa
# 3482   nm0000041  Akira Kurosawa
# 3485   nm0000041  Akira Kurosawa
# 3480   nm0000041  Akira Kurosawa
# 3478   nm0000041  Akira Kurosawa
# 3473   nm0000041  Akira Kurosawa
# 3484   nm0000041  Akira Kurosawa
# 3486   nm0000041  Akira Kurosawa
# 3490   nm0000041  Akira Kurosawa
# 3491   nm0000041  Akira Kurosawa
# 3492   nm0000041  Akira Kurosawa
# 3493   nm0000041  Akira Kurosawa
# 3494   nm0000041  Akira Kurosawa
# 3495   nm0000041  Akira Kurosawa
# 3496   nm0000041  Akira Kurosawa
# 3497   nm0000041  Akira Kurosawa
# 3498   nm0000041  Akira Kurosawa
# 3499   nm0000041  Akira Kurosawa
# 3500   nm0000041  Akira Kurosawa
